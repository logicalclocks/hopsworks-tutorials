# %% [markdown]
# ## Dataset Creation
#
# In this notebook, we will create the actual dataset that we will train our model on. In particular, we will:
# 1. Select the features we want to train our model on.
# 2. Specify how the features should be preprocessed.
# 3. Create a dataset split for training and validation data.
#
# ![tutorial-flow](images/create_training_dataset.png)

# %%
import hsfs

conn = hsfs.connection()
fs = conn.get_feature_store()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ### Feature Selection
#
# We start by selecting all the features we want to include for model training/inference.

# %%
# Load feature groups.
trans_fg = fs.get_feature_group("transactions")
window_aggs_fg = fs.get_feature_group("transactions_4h_aggs")

# Select features for training data.
ds_query = trans_fg.select(["fraud_label", "category", "amount", "age_at_transaction", "days_until_card_expires", "loc_delta"])\
    .join(window_aggs_fg.select_except(["tid"]), on="tid")\

ds_query.show(5)
# Out:
# VersionWarning: No version provided for getting feature group `transactions`, defaulting to `1`.
# VersionWarning: No version provided for getting feature group `transactions_4h_aggs`, defaulting to `1`.
# 2022-05-21 12:43:47,413 INFO: USE `fraud_demo_featurestore`
# 2022-05-21 12:43:48,351 INFO: SELECT `fg1`.`fraud_label` `fraud_label`, `fg1`.`category` `category`, `fg1`.`amount` `amount`, `fg1`.`age_at_transaction` `age_at_transaction`, `fg1`.`days_until_card_expires` `days_until_card_expires`, `fg1`.`loc_delta` `loc_delta`, `fg0`.`trans_volume_mavg` `trans_volume_mavg`, `fg0`.`trans_volume_mstd` `trans_volume_mstd`, `fg0`.`trans_freq` `trans_freq`, `fg0`.`loc_delta_mavg` `loc_delta_mavg`
# FROM `fraud_demo_featurestore`.`transactions_1` `fg1`
# INNER JOIN `fraud_demo_featurestore`.`transactions_4h_aggs_1` `fg0` ON `fg1`.`tid` = `fg0`.`tid`
#    fraud_label              category  amount  age_at_transaction  \
# 0            0  Restaurant/Cafeteria   46.39           63.809817
# 1            0    Domestic Transport   74.71           39.722159
# 2            0       Cash Withdrawal   59.60           59.887297
# 3            0       Cash Withdrawal  302.84           46.219283
# 4            0               Grocery   23.41           80.213866
#
#    days_until_card_expires  loc_delta  trans_volume_mavg  trans_volume_mstd  \
# 0               119.942917   0.000000             46.390           0.000000
# 1              1754.779306   0.043526            102.650          39.513127
# 2               190.614005   0.419421             59.600           0.000000
# 3               950.753657   0.089440            157.165         206.015561
# 4               941.486991   0.310141             23.410           0.000000
#
#    trans_freq  loc_delta_mavg
# 0         1.0    2.220446e-16
# 1         2.0    1.372198e-01
# 2         1.0    4.194213e-01
# 3         2.0    2.541432e-01
# 4         1.0    3.101409e-01

# %% [markdown]
# Recall that we computed the features in `transactions_4h_aggs` using 4-hour aggregates. If we had created multiple feature groups with identical schema for different window lengths, and wanted to include them in the join we would need to include a prefix argument in the join to avoid feature name clash. See the [documentation](https://docs.hopsworks.ai/feature-store-api/latest/generated/api/query_api/#join) for more details.

# %% [markdown]
# ### Transformation Functions
#
# We will preprocess our data using *min-max scaling* on numerical features and *label encoding* on categorical features. To do this we simply define a mapping between our features and transformation functions. This ensures that transformation functions such as *min-max scaling* are fitted only on the training data (and not the validation/test data), which ensures that there is no data leakage.

# %%
# Load transformation functions.
min_max_scaler = fs.get_transformation_function(name="min_max_scaler")
label_encoder = fs.get_transformation_function(name="label_encoder")

# Map features to transformations.
transformation_functions = {
    "category": label_encoder,
    "amount": min_max_scaler,
    "trans_volume_mavg": min_max_scaler,
    "trans_volume_mstd": min_max_scaler,
    "trans_freq": min_max_scaler,
    "loc_delta": min_max_scaler,
    "loc_delta_mavg": min_max_scaler,
    "age_at_transaction": min_max_scaler,
    "days_until_card_expires": min_max_scaler,
}

# %% [markdown]
# #### Feature View Creation
# ## TODO: FV explanation
# In order to create a Feature View we may use `fs.create_feature_view()`

# %%
# help(fs.create_feature_view)

# %%
feature_view = fs.create_feature_view(
    name='transactions_view',
    query=ds_query,
    label=["fraud_label"],
    transformation_functions=transformation_functions
)

# %% [markdown]
# ## TODO: FV exploration and some text

# %%
feature_view.get_batch_data().head(5)
# Out:
# 2022-05-21 12:45:10,660 INFO: USE `fraud_demo_featurestore`
# 2022-05-21 12:45:11,591 INFO: SELECT `fg1`.`category` `category`, `fg1`.`amount` `amount`, `fg1`.`age_at_transaction` `age_at_transaction`, `fg1`.`days_until_card_expires` `days_until_card_expires`, `fg1`.`loc_delta` `loc_delta`, `fg0`.`trans_volume_mavg` `trans_volume_mavg`, `fg0`.`trans_volume_mstd` `trans_volume_mstd`, `fg0`.`trans_freq` `trans_freq`, `fg0`.`loc_delta_mavg` `loc_delta_mavg`
# FROM `fraud_demo_featurestore`.`transactions_1` `fg1`
# INNER JOIN `fraud_demo_featurestore`.`transactions_4h_aggs_1` `fg0` ON `fg1`.`tid` = `fg0`.`tid`
#                category  amount  age_at_transaction  days_until_card_expires  \
# 0  Restaurant/Cafeteria   46.39           63.809817               119.942917
# 1    Domestic Transport   74.71           39.722159              1754.779306
# 2       Cash Withdrawal   59.60           59.887297               190.614005
# 3       Cash Withdrawal  302.84           46.219283               950.753657
# 4               Grocery   23.41           80.213866               941.486991
#
#    loc_delta  trans_volume_mavg  trans_volume_mstd  trans_freq  loc_delta_mavg
# 0   0.000000             46.390           0.000000         1.0    2.220446e-16
# 1   0.043526            102.650          39.513127         2.0    1.372198e-01
# 2   0.419421             59.600           0.000000         1.0    4.194213e-01
# 3   0.089440            157.165         206.015561         2.0    2.541432e-01
# 4   0.310141             23.410           0.000000         1.0    3.101409e-01

# %% [markdown]
# #### Training Training Dataset Creation
# ## TODO: explain diff between FV and TD
# Finally we create the dataset using `fs.create_training_dataset()`.

# %%
td_version, td_job = feature_view.create_training_dataset(
    description = 'transactions_dataset_splitted',
    data_format = 'csv',
    splits = {'train': 80, 'validation': 20},
    train_split = "train",
    write_options = {'wait_for_job': False}
)
# Out:
# Training dataset job started successfully, you can follow the progress at https://hopsworks.glassfish.service.consul:8182/p/119/jobs/named/transactions_view_1_1_create_fv_td_21052022124609/executions
# VersionWarning: No version provided for creating training dataset, incremented version to `1`.

# %% [markdown]
# ## TODO: TD exploration and some text

# %%
td_version, df = feature_view.get_training_dataset(start_time=None, end_time=None, version = td_version)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in _read_dir_from_storage_connector(self, training_data_obj, path, read_options)
#     229         try:
# --> 230             return training_data_obj.storage_connector.read(
#     231                 # always read from materialized dataset, not query object
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/storage_connector.py in read(self, query, data_format, options, path)
#     107         """
# --> 108         return engine.get_instance().read(self, data_format, options, path)
#     109
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/engine/python.py in read(self, storage_connector, data_format, read_options, location)
#      96         if storage_connector.type == storage_connector.HOPSFS:
# ---> 97             df_list = self._read_hopsfs(location, data_format)
#      98         elif storage_connector.type == storage_connector.S3:
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/engine/python.py in _read_hopsfs(self, location, data_format)
#     131         util.setup_pydoop()
# --> 132         path_list = hdfs.ls(location, recursive=True)
#     133
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/pydoop/hdfs/__init__.py in ls(hdfs_path, user, recursive)
#     306     """
# --> 307     dir_list = lsl(hdfs_path, user, recursive)
#     308     return [d["name"] for d in dir_list]
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/pydoop/hdfs/__init__.py in lsl(hdfs_path, user, recursive)
#     290         treewalk = fs.walk(path_)
# --> 291         top = next(treewalk)
#     292         if top['kind'] == 'directory':
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/pydoop/hdfs/fs.py in walk(self, top)
#     630         if isinstance(top, basestring):
# --> 631             top = self.get_path_info(top)
#     632         yield top
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/pydoop/hdfs/fs.py in get_path_info(self, path)
#     405         _complain_ifclosed(self.closed)
# --> 406         return self.fs.get_path_info(path)
#     407
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-7032c86f75a2> in <module>
# ----> 1 td_version, df = feature_view.get_training_dataset(start_time=None, end_time=None, version = td_version)
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/feature_view.py in get_training_dataset(self, start_time, end_time, version, description, statistics_config, read_options)
#     364                 Training dataset version and dataframe.
#     365         """
# --> 366         td, df = self.get_training_dataset_splits(
#     367             {},
#     368             start_time=start_time,
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/feature_view.py in get_training_dataset_splits(self, splits, start_time, end_time, version, description, statistics_config, train_split, read_options)
#     302         )
#     303         # td_job is used only if the python engine is used
# --> 304         td, df = self._feature_view_engine.get_training_data(
#     305             self, td, read_options, splits=splits
#     306         )
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in get_training_data(self, feature_view_obj, training_dataset_obj, read_options, splits)
#     189
#     190         if td_updated.training_dataset_type != training_dataset_obj.IN_MEMORY:
# --> 191             split_df = self._read_from_storage_connector(
#     192                 td_updated, splits, read_options
#     193             )
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in _read_from_storage_connector(self, training_data_obj, splits, read_options)
#     222         else:
#     223             path = training_data_obj.location + "/" + training_data_obj.name
# --> 224             return self._read_dir_from_storage_connector(
#     225                 training_data_obj, path, read_options
#     226             )
#
# /srv/hops/anaconda/envs/theenv/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in _read_dir_from_storage_connector(self, training_data_obj, path, read_options)
#     237         except Exception as e:
#     238             if isinstance(e, FileNotFoundError):
# --> 239                 raise FileNotFoundError(
#     240                     f"Failed to read dataset from {path}."
#     241                     " Check if path exists or recreate a training dataset."
#
# FileNotFoundError: Failed to read dataset from hopsfs://10.0.2.15:8020/Projects/fraud_demo/fraud_demo_Training_Datasets/transactions_view_1_1/transactions_view_1. Check if path exists or recreate a training dataset.

# %%
td_version, df = feature_view.get_training_dataset_splits({'train': 80, 'validation': 20}, start_time=None, end_time=None, version = td_version)

# %%
df

# %%
td_version
# Out:
# 1

# %%
training_dataset_obj = fs.get_training_dataset("transactions_view_1", 1)

# %%
training_dataset_obj.read("train")
# Out:
#        fraud_label  category        amount  age_at_transaction  \
# 0                0         5  0.000000e+00            0.010858
# 1                0         5  0.000000e+00            0.047378
# 2                0         5  0.000000e+00            0.063759
# 3                0         5  0.000000e+00            0.340603
# 4                0         5  3.336858e-07            0.364075
# ...            ...       ...           ...                 ...
# 84965            1         7  5.702691e-03            0.206613
# 84966            1         7  7.304049e-03            0.909331
# 84967            1         3  1.698461e-04            0.132164
# 84968            1         3  4.875150e-04            0.488983
# 84969            1         3  3.098940e-03            0.266895
#
#        days_until_card_expires  loc_delta  trans_volume_mavg  \
# 0                     0.849987   0.026437       0.000000e+00
# 1                     0.943547   0.037840       0.000000e+00
# 2                     0.129328   0.000046       0.000000e+00
# 3                     0.206006   0.224487       0.000000e+00
# 4                     0.663339   0.098624       3.336858e-07
# ...                        ...        ...                ...
# 84965                 0.226536   0.103895       2.155544e-03
# 84966                 0.728146   0.227438       4.702467e-03
# 84967                 0.815860   0.230563       1.698461e-04
# 84968                 0.605782   0.046052       4.875150e-04
# 84969                 0.268095   0.103586       3.098940e-03
#
#        trans_volume_mstd  trans_freq  loc_delta_mavg
# 0               0.000000         0.0        0.026888
# 1               0.000000         0.0        0.038485
# 2               0.000000         0.0        0.000047
# 3               0.000000         0.0        0.228318
# 4               0.000000         0.0        0.100307
# ...                  ...         ...             ...
# 84965           0.002865         0.9        0.101301
# 84966           0.005214         0.1        0.204941
# 84967           0.000000         0.0        0.234498
# 84968           0.000000         0.0        0.046838
# 84969           0.000000         0.0        0.105353
#
# [84970 rows x 10 columns]

# %%
training_dataset_obj.read("validation")
# Out:
#        fraud_label  category        amount  age_at_transaction  \
# 0                0         5  0.000000e+00            0.954661
# 1                0         5  3.336858e-07            0.961837
# 2                0         5  6.673716e-07            0.659617
# 3                0         5  6.673716e-07            0.815824
# 4                0         5  6.673716e-07            0.827326
# ...            ...       ...           ...                 ...
# 21045            1         4  2.100886e-03            0.909331
# 21046            1         4  2.690842e-03            0.206613
# 21047            1         4  2.730885e-03            0.909331
# 21048            1         4  3.267118e-03            0.909331
# 21049            1         7  1.362873e-02            0.516288
#
#        days_until_card_expires  loc_delta  trans_volume_mavg  \
# 0                     0.874445   0.194834       0.000000e+00
# 1                     0.766053   0.196517       1.365109e-03
# 2                     0.208964   0.062039       6.673716e-07
# 3                     0.767163   0.096732       6.673716e-07
# 4                     0.068374   0.100149       2.581560e-03
# ...                        ...        ...                ...
# 21045                 0.728147   0.175566       2.100886e-03
# 21046                 0.226540   0.029113       2.856851e-03
# 21047                 0.728145   0.140484       2.889330e-03
# 21048                 0.728144   0.209982       2.489482e-03
# 21049                 0.312312   0.091271       5.831589e-03
#
#        trans_volume_mstd  trans_freq  loc_delta_mavg
# 0               0.000000         0.0        0.198159
# 1               0.002735         0.1        0.146589
# 2               0.000000         0.0        0.063098
# 3               0.000000         0.0        0.098383
# 4               0.005172         0.1        0.071501
# ...                  ...         ...             ...
# 21045           0.000000         0.0        0.178562
# 21046           0.000333         0.1        0.032057
# 21047           0.003408         0.5        0.174735
# 21048           0.003008         0.8        0.167911
# 21049           0.011611         0.6        0.099539
#
# [21050 rows x 10 columns]

# %% [markdown]
# ### Next Steps
#
# In the next notebook, we will train a model on the dataset we created in this notebook.
