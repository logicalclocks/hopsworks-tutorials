# %% [markdown]
# # Tweets Feature Engineering

# %% [markdown]
# <div style="text-align:center">
# <img src="https://i.gifer.com/YHlm.gif" width='350'>
# </div>

# %% [markdown]
# ### <span style="color:#ff5f27;"> 📝 Imports</span>

# %%
import json
import io
import re
import time
import os.path
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from datetime import timedelta, datetime
from dateutil import parser

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from tqdm import tnrange, tqdm_notebook, tqdm

from sklearn import preprocessing
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## <span style='color:#ff5f27'> 🪛 Preprocessing tweets from [kaggle](https://www.kaggle.com/datasets/kaushiksuresh147/bitcoin-tweets) </span>
#
# ### I took this dataset from Kaggle because Twitter API allows us to parse only ~9-days old tweets. And here we have a couple of millions of them. So in this and next notebooks we will process this huge amount of data and in streamlit app we will just parse new recently created ones and add to our Feature Groups.

# %% [markdown]
# ## ‼️ Since [this dataset](https://www.kaggle.com/datasets/kaushiksuresh147/bitcoin-tweets) is about 600 Mb, I do not provide it in this GutHub repository, you should manually download it from Kaggle and place that file in this folder

# %%
df_tweets = pd.read_csv("Bitcoin_tweets.csv")

# %%
df_tweets.shape
# Out:
# (3543853, 13)

# %%
df_tweets.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %% [markdown]
# 1. delete all where retweet=True
# 2. keep only text, date, new quality feature (likes * followers etc)
# 3. розсосать

# %%
df_tweets.user_verified = df_tweets.user_verified.astype(str)

# %%
df_tweets_correct = df_tweets[(df_tweets["user_verified"] == "False") | (df_tweets["user_verified"] == "True")]

# %%
df_tweets_correct
# Out:
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                                       Tdlmatias
# 3                            Crypto is the future
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# ...                                           ...
# 3543848                          🔔system'cRe5520'
# 3543849                     Bitcoin Price Tracker
# 3543850                                 Astro Bot
# 3543851                            Job Preference
# 3543852            Bitcoin Price and News Updates
#
#                          user_location  \
# 0                          Atlanta, GA
# 1                                  NaN
# 2                      London, England
# 3                                  NaN
# 4                               Europa
# ...                                ...
# 3543848  AWS eu-west-1a Ireland Region
# 3543849                            NaN
# 3543850                            NaN
# 3543851                            NaN
# 3543852                            NaN
#
#                                           user_description  \
# 0        Biz Consultant, real estate, fintech, startups...
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...
# 2        IM Academy : The best #forex, #SelfEducation, ...
# 3        I will post a lot of buying signals for BTC tr...
# 4        Co-founder @RENJERJerky | Forbes 30Under30 | I...
# ...                                                    ...
# 3543848  The channel breakout trading strategy bot for ...
# 3543849             Get frequent updates on Bitcoin Price.
# 3543850  Fully Automated Trading Bot. \nCreator: @Astro...
# 3543851  You Don't Need a middleman to find a decent #J...
# 3543852                                                NaN
#
#                 user_created user_followers user_friends user_favourites  \
# 0        2009-04-26 20:05:09         8534.0         7605            4838
# 1        2019-10-17 20:12:10         6769.0         1532           25483
# 2        2014-11-10 10:50:37          128.0          332             924
# 3        2019-09-28 16:48:12          625.0          129              14
# 4        2016-02-03 13:15:55         1249.0         1472           10482
# ...                      ...            ...          ...             ...
# 3543848  2012-06-02 07:46:44          236.0         16.0            63.0
# 3543849  2022-04-01 18:46:56          628.0          2.0             1.0
# 3543850  2020-11-07 04:35:37           68.0          1.0            39.0
# 3543851  2020-11-28 15:56:01         1486.0        590.0         12165.0
# 3543852  2021-12-10 01:26:06            5.0          1.0             0.0
#
#         user_verified                 date  \
# 0               False  2021-02-10 23:59:04
# 1               False  2021-02-10 23:58:48
# 2               False  2021-02-10 23:54:48
# 3               False  2021-02-10 23:54:33
# 4               False  2021-02-10 23:54:06
# ...               ...                  ...
# 3543848         False  2022-05-30 00:00:03
# 3543849         False  2022-05-30 00:00:02
# 3543850         False  2022-05-30 00:00:02
# 3543851         False  2022-05-30 00:00:01
# 3543852         False  2022-05-30 00:00:00
#
#                                                       text  \
# 0        Blue Ridge Bank shares halted by NYSE after #b...
# 1        😎 Today, that's this #Thursday, we will do a "...
# 2        Guys evening, I have read this article about B...
# 3        $BTC A big chance in a billion! Price: \487264...
# 4        This network is secured by 9 508 nodes as of t...
# ...                                                    ...
# 3543848  strategy: 5010HL1h atr20d: 1790.98\n\n🕛30 May ...
# 3543849  $BTC Price: $29,465 \n#Bitcoin #BTC #BitcoinPr...
# 3543850  ASTRO BOT ALERT\n\n $BTCUSDT\n\n Timeframe:2h\...
# 3543851  #Hiring?\nSign up now https://t.co/o7lVlsCHXv\...
# 3543852  #Bitcoin (#BTC) Price Update:\n    \nPrice: $2...
#
#                                                   hashtags  \
# 0                                              ['bitcoin']
# 1                ['Thursday', 'Btc', 'wallet', 'security']
# 2                                                      NaN
# 3                       ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                                  ['BTC']
# ...                                                    ...
# 3543848                                  ['BTC', 'BitMEX']
# 3543849       ['Bitcoin', 'BTC', 'BitcoinPrice', 'Crypto']
# 3543850  ['AstroBotSignals', 'BTC', 'Cryptocurrency', '...
# 3543851  ['Hiring', 'Jobs', 'Java', 'Programming', 'Cod...
# 3543852                                 ['Bitcoin', 'BTC']
#
#                         source is_retweet
# 0              Twitter Web App      False
# 1          Twitter for Android      False
# 2              Twitter Web App      False
# 3                      dlvr.it      False
# 4              Twitter Web App      False
# ...                        ...        ...
# 3543848        system'cRe5520'      False
# 3543849      bitcoin_price_bot      False
# 3543850           The_AstroBot      False
# 3543851        Twitter Web App      False
# 3543852  CurrencyRushTweetBots      False
#
# [3543701 rows x 13 columns]

# %%
df_tweets_incorrect = df_tweets.drop(list(df_tweets_correct.index))

# %%
df_tweets_corrected = df_tweets_incorrect.shift(periods=2, axis="columns")

# %%
df_tweets_processed = pd.concat([df_tweets_correct, df_tweets_corrected]).sort_values(by=["date"])

# %%
del df_tweets_correct
del df_tweets_corrected

# %%
df_tweets_processed.shape
# Out:
# (3543853, 13)

# %%
df_tweets_processed.head(5)
# Out:
#               user_name               user_location  \
# 2612133             NaN                         NaN
# 21524    Iconic Holding  Frankfurt am Main, Germany
# 21523    Iconic Holding  Frankfurt am Main, Germany
# 21522    Iconic Holding  Frankfurt am Main, Germany
# 21521    Iconic Holding  Frankfurt am Main, Germany
#
#                                           user_description  \
# 2612133       Electronics: Find tech deals for smartphones
# 21524    Professional Crypto Asset Ventures \nhttps://t...
# 21523    Professional Crypto Asset Ventures \nhttps://t...
# 21522    Professional Crypto Asset Ventures \nhttps://t...
# 21521    Professional Crypto Asset Ventures \nhttps://t...
#
#                 user_created user_followers user_friends      user_favourites  \
# 2612133              watches     headphones     speakers   Laptops and more."
# 21524    2021-01-05 13:22:24          301.0         1075                  361
# 21523    2021-01-05 13:22:24          301.0         1075                  361
# 21522    2021-01-05 13:22:24          301.0         1075                  361
# 21521    2021-01-05 13:22:24          301.0         1075                  361
#
#                user_verified                 date  \
# 2612133  2021-10-09 06:21:24                  1.0
# 21524                  False  2021-02-05 10:52:04
# 21523                  False  2021-02-05 10:52:04
# 21522                  False  2021-02-05 10:52:06
# 21521                  False  2021-02-05 10:52:07
#
#                                                       text  \
# 2612133                                                 35
# 21524    📖  Weekend Read 📖\n\nKeen to learn about #cryp...
# 21523    2⃣   Debunking 9 #Bitcoin Myths by @Patrick_Lo...
# 21522    4⃣  🎙️ Bloomberg LP #CryptoOutlook 2021 with @...
# 21521    5⃣   #Blockchain 50 2021 by @DelRayMan, @Forbe...
#
#                                                   hashtags           source  \
# 2612133                                                 20            False
# 21524                                           ['crypto']  Twitter Web App
# 21523    ['Bitcoin', 'cryptocurrency', 'bitcoin', 'cryp...  Twitter Web App
# 21522    ['CryptoOutlook', 'cryptocurrency', 'bitcoin',...  Twitter Web App
# 21521    ['Blockchain', 'cryptocurrency', 'bitcoin', 'c...  Twitter Web App
#
#                   is_retweet
# 2612133  2022-03-24 16:52:46
# 21524                  False
# 21523                  False
# 21522                  False
# 21521                  False

# %%
df_tweets_processed = df_tweets_processed[df_tweets_processed.date.notna()]

# %%
df_tweets_processed = df_tweets_processed.drop(2612133)

# %%
df_tweets_processed["source"]= df_tweets_processed["source"].apply(str)
df_tweets_processed["source"]= df_tweets_processed["source"].str.lower()
df_tweets_processed = df_tweets_processed[~df_tweets_processed["source"].str.contains("bot")]

# %%
df_tweets_processed = df_tweets_processed.loc[:,["date","text", "user_followers","user_friends", "user_favourites"]]

# %%
df_tweets_processed.date = pd.to_datetime(df_tweets_processed.date)
df_tweets_processed["text"] = df_tweets_processed["text"].apply(str)

# %%
df_tweets_processed.head(5)
# Out:
#                      date                                               text  \
# 21524 2021-02-05 10:52:04  📖  Weekend Read 📖\n\nKeen to learn about #cryp...
# 21523 2021-02-05 10:52:04  2⃣   Debunking 9 #Bitcoin Myths by @Patrick_Lo...
# 21522 2021-02-05 10:52:06  4⃣  🎙️ Bloomberg LP #CryptoOutlook 2021 with @...
# 21521 2021-02-05 10:52:07  5⃣   #Blockchain 50 2021 by @DelRayMan, @Forbe...
# 21520 2021-02-05 10:52:26  #reddcoin #rdd @reddcoin to the moon #altcoin ...
#
#       user_followers user_friends user_favourites
# 21524          301.0         1075             361
# 21523          301.0         1075             361
# 21522          301.0         1075             361
# 21521          301.0         1075             361
# 21520           37.0          123             410

# %%
df_tweets_processed = df_tweets_processed.sort_values(by='date')
df_tweets_processed.reset_index(inplace=True)
df_tweets_processed.drop(columns=["index"], inplace=True)

# %%
df_tweets_processed = df_tweets_processed[["date", "text"]]

# %%
df_tweets_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3411665 entries, 0 to 3411664
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    object
#  1   text    object
# dtypes: object(2)
# memory usage: 52.1+ MB

# %% [markdown]
# ## <span style='color:#ff5f27'>🧹 Text cleaning </span>

# %%
for i,s in enumerate(tqdm(df_tweets_processed['text'],position=0, leave=True)):
    text = str(df_tweets_processed.loc[i, 'text'])
    text = text.replace("#", "")
    text = re.sub('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', '', text, flags=re.MULTILINE)
    text = re.sub('@\\w+ *', '', text, flags=re.MULTILINE)
    df_tweets_processed.loc[i, 'text'] = text

# %% [markdown]
# ## <span style='color:#ff5f27'> 📥 Save the results</span>

# %%
df_tweets_processed.to_csv("data/tweets_processed.csv")
