# %%
import hopsworks
import time
from datetime import datetime
from datetime import timedelta

project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# 2025-10-09 20:47:48,949 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://snurran.devnet.hops.works/p/4217

# %% [markdown]
# ### Get some sample user_ids for online inference tests
# Read them up from `user_clicks`

# %%
num_samples = 100

clicks_fg = fs.get_feature_group("user_clicks")
df = clicks_fg.read()

max_event_time = df['event_time'].max() 
max_event_time_dt = datetime.fromtimestamp(max_event_time)

one_min = int((max_event_time_dt - timedelta(minutes=1)).timestamp())
ten_min = int((max_event_time_dt - timedelta(minutes=10)).timestamp())
thirty_min = int((max_event_time_dt - timedelta(minutes=30)).timestamp())
one_hr = int((max_event_time_dt - timedelta(hours=1)).timestamp())

sampled_user_ids = df.sample(n=num_samples, random_state=42)
# Out:
# 2025-10-09 20:47:49,221 WARNING: VersionWarning: No version provided for getting feature group `user_clicks`, defaulting to `1`.
#
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.23s)

# %% [markdown]
# ### Use feature view to retrieve feature vectors

# %%
fv = fs.get_feature_view("precomputed_click_counts")
start = time.perf_counter()

for idx, row in sampled_user_ids.iterrows():
    user_id = row['user_id']
    r = fv.get_feature_vector(entry={"user_id": user_id})
    click_count_1_min = r[2]
    click_count_10_min = r[3]
    click_count_30_min = r[4]
    click_count_1_hour = r[5]
    print(
        f"user_id={user_id}, "
        f"click_count_1_min={click_count_1_min}, "
        f"click_count_10_min={click_count_10_min}, "
        f"click_count_30_min={click_count_30_min}, "
        f"click_count_1_hour={click_count_1_hour}"
    )
        
end = time.perf_counter()
print(f"Time taken (s): {(end-start)}")
# Out:
# 2025-10-09 20:53:48,487 WARNING: VersionWarning: No version provided for getting feature view `precomputed_click_counts`, defaulting to `1`.
#
# 2025-10-09 20:53:49,480 WARNING: VersionWarning: No training dataset version was provided to initialise serving. Defaulting to version 1.
#
# user_id=44, click_count_1_min=17, click_count_10_min=154, click_count_30_min=448, click_count_1_hour=643
# user_id=8, click_count_1_min=13, click_count_10_min=159, click_count_30_min=455, click_count_1_hour=501
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=82, click_count_1_min=14, click_count_10_min=145, click_count_30_min=430, click_count_1_hour=774
# user_id=76, click_count_1_min=13, click_count_10_min=131, click_count_30_min=355, click_count_1_hour=355
# user_id=90, click_count_1_min=15, click_count_10_min=148, click_count_30_min=363, click_count_1_hour=363
# user_id=4, click_count_1_min=17, click_count_10_min=156, click_count_30_min=462, click_count_1_hour=470
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=11, click_count_1_min=18, click_count_10_min=145, click_count_30_min=446, click_count_1_hour=530
# user_id=60, click_count_1_min=13, click_count_10_min=154, click_count_30_min=439, click_count_1_hour=558
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=10, click_count_1_min=12, click_count_10_min=125, click_count_30_min=344, click_count_1_hour=344
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=32, click_count_1_min=18, click_count_10_min=37, click_count_30_min=37, click_count_1_hour=37
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=54, click_count_1_min=13, click_count_10_min=134, click_count_30_min=173, click_count_1_hour=173
# user_id=66, click_count_1_min=11, click_count_10_min=141, click_count_30_min=415, click_count_1_hour=564
# user_id=36, click_count_1_min=15, click_count_10_min=154, click_count_30_min=361, click_count_1_hour=361
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=48, click_count_1_min=20, click_count_10_min=149, click_count_30_min=447, click_count_1_hour=832
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=84, click_count_1_min=13, click_count_10_min=139, click_count_30_min=436, click_count_1_hour=828
# user_id=55, click_count_1_min=11, click_count_10_min=129, click_count_30_min=441, click_count_1_hour=866
# user_id=26, click_count_1_min=20, click_count_10_min=164, click_count_30_min=275, click_count_1_hour=275
# user_id=45, click_count_1_min=19, click_count_10_min=170, click_count_30_min=244, click_count_1_hour=244
# user_id=54, click_count_1_min=13, click_count_10_min=134, click_count_30_min=173, click_count_1_hour=173
# user_id=80, click_count_1_min=11, click_count_10_min=152, click_count_30_min=384, click_count_1_hour=384
# user_id=22, click_count_1_min=12, click_count_10_min=114, click_count_30_min=417, click_count_1_hour=761
# user_id=80, click_count_1_min=11, click_count_10_min=152, click_count_30_min=384, click_count_1_hour=384
# user_id=77, click_count_1_min=19, click_count_10_min=173, click_count_30_min=325, click_count_1_hour=325
# user_id=16, click_count_1_min=18, click_count_10_min=135, click_count_30_min=135, click_count_1_hour=135
# user_id=55, click_count_1_min=11, click_count_10_min=129, click_count_30_min=441, click_count_1_hour=866
# user_id=26, click_count_1_min=20, click_count_10_min=164, click_count_30_min=275, click_count_1_hour=275
# user_id=68, click_count_1_min=13, click_count_10_min=156, click_count_30_min=445, click_count_1_hour=586
# user_id=100, click_count_1_min=16, click_count_10_min=127, click_count_30_min=127, click_count_1_hour=127
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=7, click_count_1_min=14, click_count_10_min=131, click_count_30_min=430, click_count_1_hour=632
# user_id=2, click_count_1_min=8, click_count_10_min=148, click_count_30_min=455, click_count_1_hour=588
# user_id=4, click_count_1_min=17, click_count_10_min=156, click_count_30_min=462, click_count_1_hour=470
# user_id=91, click_count_1_min=20, click_count_10_min=145, click_count_30_min=461, click_count_1_hour=675
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=29, click_count_1_min=11, click_count_10_min=146, click_count_30_min=202, click_count_1_hour=202
# user_id=69, click_count_1_min=14, click_count_10_min=138, click_count_30_min=138, click_count_1_hour=138
# user_id=88, click_count_1_min=17, click_count_10_min=109, click_count_30_min=109, click_count_1_hour=109
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=1, click_count_1_min=16, click_count_10_min=139, click_count_30_min=399, click_count_1_hour=817
# user_id=50, click_count_1_min=9, click_count_10_min=9, click_count_30_min=9, click_count_1_hour=9
# user_id=9, click_count_1_min=21, click_count_10_min=163, click_count_30_min=256, click_count_1_hour=256
# user_id=71, click_count_1_min=13, click_count_10_min=134, click_count_30_min=209, click_count_1_hour=209
# user_id=71, click_count_1_min=13, click_count_10_min=134, click_count_30_min=209, click_count_1_hour=209
# user_id=76, click_count_1_min=13, click_count_10_min=131, click_count_30_min=355, click_count_1_hour=355
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=61, click_count_1_min=9, click_count_10_min=143, click_count_30_min=417, click_count_1_hour=417
# user_id=96, click_count_1_min=20, click_count_10_min=151, click_count_30_min=167, click_count_1_hour=167
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=6, click_count_1_min=12, click_count_10_min=64, click_count_30_min=64, click_count_1_hour=64
# user_id=31, click_count_1_min=10, click_count_10_min=135, click_count_30_min=387, click_count_1_hour=387
# user_id=23, click_count_1_min=17, click_count_10_min=162, click_count_30_min=433, click_count_1_hour=648
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=20, click_count_1_min=12, click_count_10_min=48, click_count_30_min=48, click_count_1_hour=48
# user_id=1, click_count_1_min=16, click_count_10_min=139, click_count_30_min=399, click_count_1_hour=817
# user_id=59, click_count_1_min=22, click_count_10_min=147, click_count_30_min=259, click_count_1_hour=259
# user_id=73, click_count_1_min=17, click_count_10_min=141, click_count_30_min=331, click_count_1_hour=331
# user_id=23, click_count_1_min=17, click_count_10_min=162, click_count_30_min=433, click_count_1_hour=648
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=56, click_count_1_min=11, click_count_10_min=124, click_count_30_min=227, click_count_1_hour=227
# user_id=18, click_count_1_min=15, click_count_10_min=152, click_count_30_min=451, click_count_1_hour=672
# user_id=63, click_count_1_min=11, click_count_10_min=154, click_count_30_min=420, click_count_1_hour=420
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=33, click_count_1_min=13, click_count_10_min=137, click_count_30_min=393, click_count_1_hour=393
# user_id=44, click_count_1_min=17, click_count_10_min=154, click_count_30_min=448, click_count_1_hour=643
# user_id=15, click_count_1_min=18, click_count_10_min=158, click_count_30_min=282, click_count_1_hour=282
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=100, click_count_1_min=16, click_count_10_min=127, click_count_30_min=127, click_count_1_hour=127
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=41, click_count_1_min=14, click_count_10_min=153, click_count_30_min=429, click_count_1_hour=455
# user_id=92, click_count_1_min=11, click_count_10_min=144, click_count_30_min=424, click_count_1_hour=774
# user_id=91, click_count_1_min=20, click_count_10_min=145, click_count_30_min=461, click_count_1_hour=675
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=67, click_count_1_min=12, click_count_10_min=91, click_count_30_min=91, click_count_1_hour=91
# user_id=13, click_count_1_min=19, click_count_10_min=153, click_count_30_min=452, click_count_1_hour=839
# user_id=38, click_count_1_min=16, click_count_10_min=157, click_count_30_min=458, click_count_1_hour=487
# user_id=48, click_count_1_min=20, click_count_10_min=149, click_count_30_min=447, click_count_1_hour=832
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=84, click_count_1_min=13, click_count_10_min=139, click_count_30_min=436, click_count_1_hour=828
# user_id=5, click_count_1_min=13, click_count_10_min=164, click_count_30_min=446, click_count_1_hour=765
# user_id=78, click_count_1_min=14, click_count_10_min=142, click_count_30_min=440, click_count_1_hour=709
# user_id=96, click_count_1_min=20, click_count_10_min=151, click_count_30_min=167, click_count_1_hour=167
# user_id=13, click_count_1_min=19, click_count_10_min=153, click_count_30_min=452, click_count_1_hour=839
# user_id=52, click_count_1_min=13, click_count_10_min=148, click_count_30_min=455, click_count_1_hour=666
# user_id=62, click_count_1_min=14, click_count_10_min=149, click_count_30_min=208, click_count_1_hour=208
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# Time taken (s): 1.9908718401566148

# %% [markdown]
# ### Benchmark with MySQL Client
# For extra performance, we can go directly to the MySQL Server.

# %%
import pymysql

host = "onlinefs.mysql.service.consul"
port = 3306
database = "aggregations"
user = "aggregations_jim00000"
password = "tRwvOWqSFNUOaIXzXyaIzDIfIKxjQSzG"

conn = pymysql.connect(
    host=host,
    port=port,
    user=user,
    password=password,
    database=database,
    ssl=None  
)

start = time.perf_counter()
total_count = 0
for idx, row in sampled_user_ids.iterrows():
    user_id = row['user_id']
    cursor = conn.cursor()
    query = "SELECT * FROM precomputed_click_counts_1 WHERE user_id = %s"
    cursor.execute(query, (user_id,))
    r = cursor.fetchone()
    cursor.close()
    click_count_1_min = r[2]
    click_count_10_min = r[3]
    click_count_30_min = r[4]
    click_count_1_hour = r[5]
    total_count += 1
    print(
        f"user_id={user_id}, "
        f"click_count_1_min={click_count_1_min}, "
        f"click_count_10_min={click_count_10_min}, "
        f"click_count_30_min={click_count_30_min}, "
        f"click_count_1_hour={click_count_1_hour}"
    )
end = time.perf_counter()
print(f"Time taken (s): {(end-start)}")
print(f"Total Count: {total_count}")

conn.close()
# Out:
# user_id=44, click_count_1_min=17, click_count_10_min=154, click_count_30_min=448, click_count_1_hour=643
# user_id=8, click_count_1_min=13, click_count_10_min=159, click_count_30_min=455, click_count_1_hour=501
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=82, click_count_1_min=14, click_count_10_min=145, click_count_30_min=430, click_count_1_hour=774
# user_id=76, click_count_1_min=13, click_count_10_min=131, click_count_30_min=355, click_count_1_hour=355
# user_id=90, click_count_1_min=15, click_count_10_min=148, click_count_30_min=363, click_count_1_hour=363
# user_id=4, click_count_1_min=17, click_count_10_min=156, click_count_30_min=462, click_count_1_hour=470
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=11, click_count_1_min=18, click_count_10_min=145, click_count_30_min=446, click_count_1_hour=530
# user_id=60, click_count_1_min=13, click_count_10_min=154, click_count_30_min=439, click_count_1_hour=558
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=10, click_count_1_min=12, click_count_10_min=125, click_count_30_min=344, click_count_1_hour=344
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=32, click_count_1_min=18, click_count_10_min=37, click_count_30_min=37, click_count_1_hour=37
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=54, click_count_1_min=13, click_count_10_min=134, click_count_30_min=173, click_count_1_hour=173
# user_id=66, click_count_1_min=11, click_count_10_min=141, click_count_30_min=415, click_count_1_hour=564
# user_id=36, click_count_1_min=15, click_count_10_min=154, click_count_30_min=361, click_count_1_hour=361
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=48, click_count_1_min=20, click_count_10_min=149, click_count_30_min=447, click_count_1_hour=832
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=84, click_count_1_min=13, click_count_10_min=139, click_count_30_min=436, click_count_1_hour=828
# user_id=55, click_count_1_min=11, click_count_10_min=129, click_count_30_min=441, click_count_1_hour=866
# user_id=26, click_count_1_min=20, click_count_10_min=164, click_count_30_min=275, click_count_1_hour=275
# user_id=45, click_count_1_min=19, click_count_10_min=170, click_count_30_min=244, click_count_1_hour=244
# user_id=54, click_count_1_min=13, click_count_10_min=134, click_count_30_min=173, click_count_1_hour=173
# user_id=80, click_count_1_min=11, click_count_10_min=152, click_count_30_min=384, click_count_1_hour=384
# user_id=22, click_count_1_min=12, click_count_10_min=114, click_count_30_min=417, click_count_1_hour=761
# user_id=80, click_count_1_min=11, click_count_10_min=152, click_count_30_min=384, click_count_1_hour=384
# user_id=77, click_count_1_min=19, click_count_10_min=173, click_count_30_min=325, click_count_1_hour=325
# user_id=16, click_count_1_min=18, click_count_10_min=135, click_count_30_min=135, click_count_1_hour=135
# user_id=55, click_count_1_min=11, click_count_10_min=129, click_count_30_min=441, click_count_1_hour=866
# user_id=26, click_count_1_min=20, click_count_10_min=164, click_count_30_min=275, click_count_1_hour=275
# user_id=68, click_count_1_min=13, click_count_10_min=156, click_count_30_min=445, click_count_1_hour=586
# user_id=100, click_count_1_min=16, click_count_10_min=127, click_count_30_min=127, click_count_1_hour=127
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=7, click_count_1_min=14, click_count_10_min=131, click_count_30_min=430, click_count_1_hour=632
# user_id=2, click_count_1_min=8, click_count_10_min=148, click_count_30_min=455, click_count_1_hour=588
# user_id=4, click_count_1_min=17, click_count_10_min=156, click_count_30_min=462, click_count_1_hour=470
# user_id=91, click_count_1_min=20, click_count_10_min=145, click_count_30_min=461, click_count_1_hour=675
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=29, click_count_1_min=11, click_count_10_min=146, click_count_30_min=202, click_count_1_hour=202
# user_id=69, click_count_1_min=14, click_count_10_min=138, click_count_30_min=138, click_count_1_hour=138
# user_id=88, click_count_1_min=17, click_count_10_min=109, click_count_30_min=109, click_count_1_hour=109
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=1, click_count_1_min=16, click_count_10_min=139, click_count_30_min=399, click_count_1_hour=817
# user_id=50, click_count_1_min=9, click_count_10_min=9, click_count_30_min=9, click_count_1_hour=9
# user_id=9, click_count_1_min=21, click_count_10_min=163, click_count_30_min=256, click_count_1_hour=256
# user_id=71, click_count_1_min=13, click_count_10_min=134, click_count_30_min=209, click_count_1_hour=209
# user_id=71, click_count_1_min=13, click_count_10_min=134, click_count_30_min=209, click_count_1_hour=209
# user_id=76, click_count_1_min=13, click_count_10_min=131, click_count_30_min=355, click_count_1_hour=355
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=61, click_count_1_min=9, click_count_10_min=143, click_count_30_min=417, click_count_1_hour=417
# user_id=96, click_count_1_min=20, click_count_10_min=151, click_count_30_min=167, click_count_1_hour=167
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# user_id=6, click_count_1_min=12, click_count_10_min=64, click_count_30_min=64, click_count_1_hour=64
# user_id=31, click_count_1_min=10, click_count_10_min=135, click_count_30_min=387, click_count_1_hour=387
# user_id=23, click_count_1_min=17, click_count_10_min=162, click_count_30_min=433, click_count_1_hour=648
# user_id=27, click_count_1_min=16, click_count_10_min=70, click_count_30_min=70, click_count_1_hour=70
# user_id=20, click_count_1_min=12, click_count_10_min=48, click_count_30_min=48, click_count_1_hour=48
# user_id=1, click_count_1_min=16, click_count_10_min=139, click_count_30_min=399, click_count_1_hour=817
# user_id=59, click_count_1_min=22, click_count_10_min=147, click_count_30_min=259, click_count_1_hour=259
# user_id=73, click_count_1_min=17, click_count_10_min=141, click_count_30_min=331, click_count_1_hour=331
# user_id=23, click_count_1_min=17, click_count_10_min=162, click_count_30_min=433, click_count_1_hour=648
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=56, click_count_1_min=11, click_count_10_min=124, click_count_30_min=227, click_count_1_hour=227
# user_id=18, click_count_1_min=15, click_count_10_min=152, click_count_30_min=451, click_count_1_hour=672
# user_id=63, click_count_1_min=11, click_count_10_min=154, click_count_30_min=420, click_count_1_hour=420
# user_id=89, click_count_1_min=19, click_count_10_min=160, click_count_30_min=403, click_count_1_hour=403
# user_id=49, click_count_1_min=16, click_count_10_min=143, click_count_30_min=411, click_count_1_hour=754
# user_id=33, click_count_1_min=13, click_count_10_min=137, click_count_30_min=393, click_count_1_hour=393
# user_id=44, click_count_1_min=17, click_count_10_min=154, click_count_30_min=448, click_count_1_hour=643
# user_id=15, click_count_1_min=18, click_count_10_min=158, click_count_30_min=282, click_count_1_hour=282
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=100, click_count_1_min=16, click_count_10_min=127, click_count_30_min=127, click_count_1_hour=127
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=25, click_count_1_min=21, click_count_10_min=154, click_count_30_min=466, click_count_1_hour=765
# user_id=72, click_count_1_min=14, click_count_10_min=73, click_count_30_min=73, click_count_1_hour=73
# user_id=41, click_count_1_min=14, click_count_10_min=153, click_count_30_min=429, click_count_1_hour=455
# user_id=92, click_count_1_min=11, click_count_10_min=144, click_count_30_min=424, click_count_1_hour=774
# user_id=91, click_count_1_min=20, click_count_10_min=145, click_count_30_min=461, click_count_1_hour=675
# user_id=47, click_count_1_min=13, click_count_10_min=141, click_count_30_min=306, click_count_1_hour=306
# user_id=67, click_count_1_min=12, click_count_10_min=91, click_count_30_min=91, click_count_1_hour=91
# user_id=13, click_count_1_min=19, click_count_10_min=153, click_count_30_min=452, click_count_1_hour=839
# user_id=38, click_count_1_min=16, click_count_10_min=157, click_count_30_min=458, click_count_1_hour=487
# user_id=48, click_count_1_min=20, click_count_10_min=149, click_count_30_min=447, click_count_1_hour=832
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=84, click_count_1_min=13, click_count_10_min=139, click_count_30_min=436, click_count_1_hour=828
# user_id=5, click_count_1_min=13, click_count_10_min=164, click_count_30_min=446, click_count_1_hour=765
# user_id=78, click_count_1_min=14, click_count_10_min=142, click_count_30_min=440, click_count_1_hour=709
# user_id=96, click_count_1_min=20, click_count_10_min=151, click_count_30_min=167, click_count_1_hour=167
# user_id=13, click_count_1_min=19, click_count_10_min=153, click_count_30_min=452, click_count_1_hour=839
# user_id=52, click_count_1_min=13, click_count_10_min=148, click_count_30_min=455, click_count_1_hour=666
# user_id=62, click_count_1_min=14, click_count_10_min=149, click_count_30_min=208, click_count_1_hour=208
# user_id=58, click_count_1_min=20, click_count_10_min=162, click_count_30_min=453, click_count_1_hour=576
# user_id=93, click_count_1_min=11, click_count_10_min=145, click_count_30_min=428, click_count_1_hour=860
# Time taken (s): 0.1128736361861229
# Total Count: 100
